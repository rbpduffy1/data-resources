# %% [markdown]
# # Text Analysis (Apple tweets)
#
# This notebook explores a dataset of tweets that included `@apple`.
#
# ### Imports

# %%
import pandas as pd # For dataframe manipulation

import nltk  # machine learning with text

from nltk.corpus import stopwords, wordnet  # List of common words

from nltk.tokenize import word_tokenize  # Split text into significant forms

from nltk.stem import WordNetLemmatizer  # Reduce words to their root form ("lemma")

from nltk import pos_tag  # Tag words with parts of speech

from collections import defaultdict  # Dictionaries that have a backup value

from sklearn.feature_extraction.text import CountVectorizer  # Convert text to sparse matrices

import matplotlib.pyplot as plt  # Complex visualisation configuration

import seaborn as sns  # Visualisation

from wordcloud import WordCloud  # Create wordclouds

from textblob import TextBlob  # Sentiment analysis

from gensim.models.ldamodel import LdaModel  # Topic extraction

from gensim.models.phrases import Phrases  # ngrams

from gensim import corpora  # Vectorization

import pyLDAvis.gensim  # Visualise topics

# %%
# Install necessary dependencies from NLTK
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/danielkeefe/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danielkeefe/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/danielkeefe/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Data sourcing

# %%
# Load the data from a .csv

tweets = pd.read_csv("apple_tweets.csv")

# %% [markdown]
# ### Data exploration

# %%
# Inspect the data

tweets.head()
# Out:
#      user_id     status_id  created_at   screen_name  \
# 0  5746452.0  1.090372e+18  1548799817  waltmossberg
# 1  5746452.0  1.090374e+18  1548800328  waltmossberg
# 2  5746452.0  1.090382e+18  1548802301  waltmossberg
# 3  5746452.0  1.090373e+18  1548800242  waltmossberg
# 4  1175221.0  1.090110e+18  1548737368     digiphile
#
#                                                 text              source  \
# 0  It’s true that @Apple likely overpriced the la...    Twitter for iPad
# 1                   @AaronSuplizio @Apple Yes it is.    Twitter for iPad
# 2  @mvigod @Apple As I have said many times here,...    Twitter for iPad
# 3  I’m not saying that @Apple doesn’t have proble...    Twitter for iPad
# 4  @DaveLeeBBC @Apple @NYGovCuomo Nor I; saw it g...  Twitter for iPhone
#
#    display_text_width  reply_to_status_id  reply_to_user_id  \
# 0                 279                 NaN               NaN
# 1                  10        1.090373e+18      2.365419e+07
# 2                 259        1.090381e+18      2.224800e+08
# 3                 270        1.090372e+18      5.746452e+06
# 4                  88        1.090109e+18      1.251786e+09
#
#   reply_to_screen_name  ...  statuses_count  favourites_count  \
# 0                  NaN  ...           21783             31007
# 1        AaronSuplizio  ...           21783             31007
# 2               mvigod  ...           21783             31007
# 3         waltmossberg  ...           21783             31007
# 4           DaveLeeBBC  ...          165604            108196
#
#    account_created_at  verified              profile_url  \
# 0          1178213411      True  https://t.co/AH9VhHsJmY
# 1          1178213411      True  https://t.co/AH9VhHsJmY
# 2          1178213411      True  https://t.co/AH9VhHsJmY
# 3          1178213411      True  https://t.co/AH9VhHsJmY
# 4          1173899540      True  https://t.co/QWOxhaw2kk
#
#                                 profile_expanded_url account_lang  \
# 0  http://www.theverge.com/label/walt-mossberg-verge           en
# 1  http://www.theverge.com/label/walt-mossberg-verge           en
# 2  http://www.theverge.com/label/walt-mossberg-verge           en
# 3  http://www.theverge.com/label/walt-mossberg-verge           en
# 4                      https://digiphile.info/about/           en
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/5746452/...
# 1  https://pbs.twimg.com/profile_banners/5746452/...
# 2  https://pbs.twimg.com/profile_banners/5746452/...
# 3  https://pbs.twimg.com/profile_banners/5746452/...
# 4  https://pbs.twimg.com/profile_banners/1175221/...
#
#                               profile_background_url  \
# 0   http://abs.twimg.com/images/themes/theme9/bg.gif
# 1   http://abs.twimg.com/images/themes/theme9/bg.gif
# 2   http://abs.twimg.com/images/themes/theme9/bg.gif
# 3   http://abs.twimg.com/images/themes/theme9/bg.gif
# 4  http://abs.twimg.com/images/themes/theme15/bg.png
#
#                                    profile_image_url
# 0  http://pbs.twimg.com/profile_images/4637351296...
# 1  http://pbs.twimg.com/profile_images/4637351296...
# 2  http://pbs.twimg.com/profile_images/4637351296...
# 3  http://pbs.twimg.com/profile_images/4637351296...
# 4  http://pbs.twimg.com/profile_images/1076306605...
#
# [5 rows x 88 columns]

# %%
# Get the number of rows & columns

print("Rows:", tweets.shape[0])
print("Columns:", tweets.shape[1])
# Out:
# Rows: 9991
# Columns: 88

# %% [markdown]
# ### Data cleaning

# %%
# Keep only interesting columns

tweets = tweets[["screen_name", "text",
                 "source", "favorite_count",
                 "retweet_count", "verified",
                 "followers_count"]]

# %%
# Check for NaN values

tweets.isna().sum()
# Out:
# screen_name        0
# text               0
# source             0
# favorite_count     0
# retweet_count      0
# verified           0
# followers_count    0
# dtype: int64

# %%
# Display the data again

tweets.sample(5)
# Out:
#         screen_name                                               text  \
# 1924       APKeyton  @waltmossberg @Apple Who cares if Mac would be...
# 6120  _tyannosaurus  *Us: Crying about @apple stupid ass FaceTime u...
# 8218      keknotbot  @Apple hey thanks for your awesome customer se...
# 3043       HARJGTWO  Now @Apple what happens now since BOTH music i...
# 6041      ShonOnHer  I think my phone hacked🤦🏽‍♂️ @Apple you have a...
#
#                   source  favorite_count  retweet_count  verified  \
# 1924  Twitter Web Client               1              0     False
# 6120  Twitter for iPhone               8              1     False
# 8218  Twitter for iPhone               0              0     False
# 3043  Twitter for iPhone               0              0     False
# 6041  Twitter for iPhone               0              0     False
#
#       followers_count
# 1924              219
# 6120              135
# 8218               20
# 3043              413
# 6041             1819

# %% [markdown]
# ### Text cleaning (punctuation)

# %%
# Pull a random tweet's text, consider the problems with it

list(tweets.sample().iloc[0])[1]

# There are multiple ways of doing the above, all of them annoying and fiddly.
# Out:
# 'Security loophole! @Apple offline #Faceline due to a major security issue.\n#Apple #security\nSource: GSMArena\nhttps://t.co/clcaoWq0jW https://t.co/sxBhGOD2bQ'

# %%
# Convert everything to lower case for simplicity's sake

tweets["text"] = tweets["text"].str.lower()

# %%
# Deal with quote marks being difficult

tweets["text"] = tweets["text"].replace(to_replace="(\u2019)", value="'", regex=True)

# Replace the most common contractions

tweets["text"] = tweets["text"].replace(to_replace="n't", value=" not", regex=True)

tweets["text"] = tweets["text"].replace(to_replace="it's", value="it is", regex=True)

tweets["text"] = tweets["text"].replace(to_replace="i've", value="i have", regex=True)

tweets["text"] = tweets["text"].replace(to_replace="i'm", value="i am", regex=True)

tweets["text"] = tweets["text"].replace(to_replace="'s", value="", regex=True)

# %%
# Remove @s and hashtags

tweets["text"] = tweets["text"].replace(to_replace=r"[#@][^\s]+", value=" ", regex=True)

# %%
# Remove links

tweets["text"] = tweets["text"].replace(to_replace=r"http[s]?:\/\/[^\s]+", value="", regex=True)

# %%
# Remove numbers

tweets["text"] = tweets["text"].replace(to_replace=r"\d+", value="", regex=True)

# %%
# Remove standard punctuation and replace with spaces

tweets["text"] = tweets["text"].replace(to_replace=r"\W", value=" ", regex=True)

# %%
# Remove extra spaces

tweets["text"] = tweets["text"].replace(to_replace=r"\s+", value=" ", regex=True)

# %%
tweets["text"].head()
# Out:
# 0    it is true that likely overpriced the latest i...
# 1                                           yes it is
# 2     as i have said many times here with regard to...
# 3    i am not saying that does not have problems an...
# 4     nor i saw it go by and then tracked it down t...
# Name: text, dtype: object

# %% [markdown]
# ### Text cleaning (words)

# %%
# Tokenise the words so they can be dealt with individually

tweets["text"] = tweets["text"].apply(word_tokenize)

# %%
# Lemmatize the words, reducing them back to their roots

# Object to lemmatize words 

lemma = WordNetLemmatizer()

# Dictionary to convert between part-of-speech tags and the ones the lemmatizer understands

tag_dict = defaultdict(lambda : wordnet.NOUN)
tag_dict['J'] = wordnet.ADJ
tag_dict['V'] = wordnet.VERB
tag_dict['R'] = wordnet.ADV

# function to lemmatize a sentence

def get_lemma(word):
    """Gets the POS tag for a word, and then returns the lemmatized form of the word"""
    tag = pos_tag([word])[0][1][0]
    tag = tag_dict[tag]
    
    return lemma.lemmatize(word, tag)

# Actually perform the lemmatization

tweets["text"] = tweets["text"].apply(lambda x: [get_lemma(word) for word in x])

# %%
# Remove common words

stop_words = stopwords.words("english")
stop_words.extend(["apple"])  # Add specific words

# Filter the words, removing the ones in stop_words and those of <=2 letters
tweets["text"] = tweets["text"].apply(lambda x: [y for y in x if y not in stop_words
                                                              and len(y) > 2])

# %%
# Drop rows with zero words remaining

tweets = tweets[tweets["text"].str.len() > 0]

# %%
# Check the new shape

print("Rows:", tweets.shape[0])
print("Columns:", tweets.shape[1])
# Out:
# Rows: 9897
# Columns: 6

# %%
# Join the lists of words back into strings

tweets["text"] = tweets["text"].apply(lambda x: " ".join(x))

# %%
# Inspect the data again

tweets["text"].head()
# Out:
# 0    true likely overprice late iphones mature mark...
# 1                                                  yes
# 2    say many time regard multiple company market c...
# 3    say problem challenge say perspective order ma...
# 4                                  saw tracked confirm
# Name: text, dtype: object

# %% [markdown]
# ### Data exploration (text)

# %%
# How many rows does the word 'bug' appear in?

tweets[tweets["text"].str.contains("apple")]["text"].count()
# Out:
# 14

# %%
# Create a document-term matrix

# Create an object that converts strings into a sparse matrix

vectorizer = CountVectorizer(max_features= 10000 , min_df=0.01, ngram_range= (1,1))

# Convert the text column to a sparse matrix

tweets_dtm = vectorizer.fit_transform(tweets["text"])

# %%
# View the bag-of-words model

tweets_dtm
# Out:
# <9897x136 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31180 stored elements in Compressed Sparse Row format>

# %%
# Create a dataframe of terms and frequencies

# Get the frequency of each term

term_frequencies = tweets_dtm.sum(axis=0)

# Match frequencies to terms

frequent_terms = [(word, term_frequencies[0, id]) for word, id in vectorizer.vocabulary_.items()]

# Convert the word-frequency pairings to a dataframe

term_df = pd.DataFrame(columns=["term",
                                   "frequency"], data=frequent_terms)

# Sort the dataframe

term_df.sort_values(by="frequency", ascending=False, inplace=True)

# %%
# Inspect the most frequent terms

term_df.head(10)
# Out:
#          term  frequency
# 80        get       1110
# 15     iphone       1084
# 69      phone        949
# 105  facetime        737
# 20        new        700
# 59       like        644
# 65       make        640
# 21        fix        623
# 27        use        534
# 49       need        529

# %% [markdown]
# ### Data visualisation

# %%
# Set figure size

plt.figure(figsize = (10,10))

# Plot the most frequent terms
sns.barplot(x="frequency", y="term", data=term_df.head(20))

# %% [markdown]
# ### Word cloud

# %%
# Create a dictionary of most frequent terms ((required for word clouds)

term_dict = term_df.set_index('term')['frequency'].to_dict()

# Create a wordcloud of most frequent terms

wc = WordCloud(width=800, height=300, background_color="white",
               max_words=100)

wc.generate_from_frequencies(term_dict)

# Display the cloud

plt.figure(figsize=(20, 10))

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Sentiment analysis

# %%
# Assign sentiment to each tweet

tweets["sentiment"] = tweets["text"].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
# Examine the worst tweets

tweets.sort_values(by="sentiment", ascending=True)[["text", "sentiment"]].head(10)
# Out:
#                                                    text  sentiment
# 3213                                  insane ever heard       -1.0
# 690              never expect even get pathetic service       -1.0
# 2759                       assume qcom trading terribly       -1.0
# 8525  either need fix conference call iphone max hor...       -1.0
# 2845  everyone worried facetime glitch concerned thi...       -1.0
# 5201                                 dam facetime nasty       -1.0
# 9414  tech company paint company pathetic way sell t...       -1.0
# 9413                           phone par lcd cruel joke       -1.0
# 4662   terrible everyone disable facetime need fix asap       -1.0
# 2393  sans credit still try get iron egregious bug d...       -1.0

# %% [markdown]
# ### Topic analysis

# %%
# extract just the text column as a list of lists

tweet_topics = list(tweets["text"].apply(lambda x: x.split(" ")))

# Create a gensim dictionary of terms from the text
# Map each word to an id

topic_dict = corpora.Dictionary(tweet_topics)

# Use the dictionary to generate a corpus from the texts
# Convert the keywords into dictionary references

topic_corpus = [topic_dict.doc2bow(text) for text in tweet_topics]

# %%
# Identify topics 

topic_model = LdaModel(topic_corpus, num_topics=5, id2word=topic_dict, passes=15)

# %%
# Visualise topics
# This is a slow and computationally expensive process - my machine's fan goes crazy during it. 

# Create the display 

lda_display = pyLDAvis.gensim.prepare(topic_model, topic_corpus, topic_dict, sort_topics=False)

# Actually display the visualisation

pyLDAvis.display(lda_display)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el3693450899977766660289862"></div>
# <script type="text/javascript">
#
# var ldavis_el3693450899977766660289862_data = {"mdsDat": {"x": [-0.11444078189266448, 0.10182723370868403, -0.1373423951368395, 0.18720825235538963, -0.03725230903456973], "y": [-0.05014558907635248, -0.14889239525201692, -0.05148578134118864, 0.052053725823327034, 0.19847003984623093], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [28.895578384399414, 15.117645263671875, 23.530956268310547, 14.130987167358398, 18.324844360351562]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5"], "Freq": [1016.0, 928.0, 320.0, 608.0, 570.0, 1032.0, ...
